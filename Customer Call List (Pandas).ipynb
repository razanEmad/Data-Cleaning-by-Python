# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\razan\Downloads\Assignments Data Analysis\7 - Customer Call List ( Problem pandas python).xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.set_index('CustomerID')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df=df.drop(columns='Not_Useful_Column')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           N/a
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df.isnull().any()
# Out:
# First_Name         False
# Last_Name           True
# Phone_Number        True
# Address            False
# Paying Customer    False
# Do_Not_Contact      True
# dtype: bool

# %%
import numpy as np

# %%
df=df.replace('N/a',np.nan)
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger           NaN
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN           NaN
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee           NaN
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df['Phone_Number'] = df['Phone_Number'].fillna(0)

# %%
df[df.isnull().any(axis=1)]
# Out:
#            First_Name  Last_Name Phone_Number               Address  \
# CustomerID
# 1003           Walter     /White   7066950392    298 Drugs Driveway
# 1009          Gandalf        NaN            0      123 Middle Earth
# 1012            Harry  ...Potter   7066950392  2394 Hogwarts Avenue
# 1018            Clark       Kent   7066950392       3498 Super Lane
# 1019            Creed     Braton            0                   NaN
#
#            Paying Customer Do_Not_Contact
# CustomerID
# 1003                     N            NaN
# 1009                   Yes            NaN
# 1012                     Y            NaN
# 1018                     Y            NaN
# 1019                   NaN            Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 1001 to 1020
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   First_Name       20 non-null     object
#  1   Last_Name        19 non-null     object
#  2   Phone_Number     20 non-null     object
#  3   Address          19 non-null     object
#  4   Paying Customer  19 non-null     object
#  5   Do_Not_Contact   16 non-null     object
# dtypes: object(6)
# memory usage: 1.1+ KB

# %%
df=df.drop(1019)
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger             0
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN             0
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee             0
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#            First_Name  Last_Name Phone_Number               Address  \
# CustomerID
# 1003           Walter     /White   7066950392    298 Drugs Driveway
# 1009          Gandalf        NaN            0      123 Middle Earth
# 1012            Harry  ...Potter   7066950392  2394 Hogwarts Avenue
# 1018            Clark       Kent   7066950392       3498 Super Lane
#
#            Paying Customer Do_Not_Contact
# CustomerID
# 1003                     N            NaN
# 1009                   Yes            NaN
# 1012                     Y            NaN
# 1018                     Y            NaN

# %%
df=df.rename(columns={'Paying Customer':'Purchased'})
df
# Out:
#            First_Name   Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421       Yes             No
# 1002             Abed       Nadir  123-643-9775        No            Yes
# 1003           Walter       White           NaN        No             No
# 1004           Dwight     Schrute  123-543-2345       Yes            Yes
# 1005              Jon        Snow  876-678-3469       Yes             No
# 1006              Ron     Swanson  304-762-2467       Yes            Yes
# 1007             Jeff      Winger           NaN        No             No
# 1008         Sherlock      Holmes  876-678-3469        No             No
# 1009          Gandalf     Unknown           NaN       Yes             No
# 1010            Peter      Parker  123-545-5421       Yes             No
# 1011          Samwise      Gamgee           NaN       Yes             No
# 1012            Harry      Potter           NaN       Yes             No
# ...

# %%
df[['Purchased','Do_Not_Contact']]= df[['Purchased','Do_Not_Contact']].replace({'Y':'Yes','N':'No'})
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger             0
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN             0
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee             0
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %% [raw]
# ### I made the Do_Not_Contact No by default so i replace the null with No:

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].replace(np.nan,'No')
df
# Out:
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# 1006              Ron      Swanson  304-762-2467
# 1007             Jeff       Winger             0
# 1008         Sherlock       Holmes  876|678|3469
# 1009          Gandalf          NaN             0
# 1010            Peter       Parker  123-545-5421
# 1011          Samwise       Gamgee             0
# 1012            Harry    ...Potter    7066950392
# 1013              Don       Draper  123-543-2345
# 1014           Leslie        Knope  876|678|3469
# 1015             Toby  Flenderson_  304-762-2467
# 1016              Ron      Weasley  123-545-5421
# 1017         Michael         Scott  123/643/9775
# 1018            Clark         Kent    7066950392
# ...

# %%
df.Phone_Number.replace(0,np.nan,inplace=True)
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_29880\591476222.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Phone_Number.replace(0,np.nan,inplace=True)
#            First_Name    Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo      Baggins  123-545-5421
# 1002             Abed        Nadir  123/643/9775
# 1003           Walter       /White    7066950392
# 1004           Dwight      Schrute  123-543-2345
# 1005              Jon         Snow  876|678|3469
# ...

# %%
df.Last_Name.str.contains('_')
# Out:
# CustomerID
# 1001    False
# 1002    False
# 1003    False
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# 1009      NaN
# 1010    False
# 1011    False
# 1012    False
# 1013    False
# 1014    False
# 1015     True
# 1016    False
# 1017    False
# 1018    False
# 1020    False
# Name: Last_Name, dtype: object

# %%
df['Last_Name']=df['Last_Name'].str.rstrip('_')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter      /White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry   ...Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
df['Last_Name']=df['Last_Name'].str.lstrip('/.')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123/643/9775
# 1003           Walter       White    7066950392
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876|678|3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876|678|3469
# 1009          Gandalf         NaN           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter    7066950392
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876|678|3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123/643/9775
# 1018            Clark        Kent    7066950392
# ...

# %%
df.Phone_Number=df.Phone_Number.str.replace('/','-')
df.Phone_Number=df.Phone_Number.str.replace('|','-')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White           NaN
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf         NaN           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter           NaN
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent           NaN
# ...

# %%
df.Last_Name=df.Last_Name.replace(np.nan,'Unknown')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White           NaN
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf     Unknown           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter           NaN
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent           NaN
# ...

# %%
df[['Street','City','ZIP Code']]=df['Address'].str.split(pat=',',expand=True)
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White           NaN
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf     Unknown           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter           NaN
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent           NaN
# ...

# %%
df=df.drop(columns='ZIP Code')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White           NaN
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf     Unknown           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter           NaN
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent           NaN
# ...

# %%
df.City=df.City.replace(np.nan,'Other')
df
# Out:
#            First_Name   Last_Name  Phone_Number  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421
# 1002             Abed       Nadir  123-643-9775
# 1003           Walter       White           NaN
# 1004           Dwight     Schrute  123-543-2345
# 1005              Jon        Snow  876-678-3469
# 1006              Ron     Swanson  304-762-2467
# 1007             Jeff      Winger           NaN
# 1008         Sherlock      Holmes  876-678-3469
# 1009          Gandalf     Unknown           NaN
# 1010            Peter      Parker  123-545-5421
# 1011          Samwise      Gamgee           NaN
# 1012            Harry      Potter           NaN
# 1013              Don      Draper  123-543-2345
# 1014           Leslie       Knope  876-678-3469
# 1015             Toby  Flenderson  304-762-2467
# 1016              Ron     Weasley  123-545-5421
# 1017         Michael        Scott  123-643-9775
# 1018            Clark        Kent           NaN
# ...

# %%
df=df.drop(columns='Address')
df
# Out:
#            First_Name   Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421       Yes             No
# 1002             Abed       Nadir  123-643-9775        No            Yes
# 1003           Walter       White           NaN        No             No
# 1004           Dwight     Schrute  123-543-2345       Yes            Yes
# 1005              Jon        Snow  876-678-3469       Yes             No
# 1006              Ron     Swanson  304-762-2467       Yes            Yes
# 1007             Jeff      Winger           NaN        No             No
# 1008         Sherlock      Holmes  876-678-3469        No             No
# 1009          Gandalf     Unknown           NaN       Yes             No
# 1010            Peter      Parker  123-545-5421       Yes             No
# 1011          Samwise      Gamgee           NaN       Yes             No
# 1012            Harry      Potter           NaN       Yes             No
# ...

# %%
print ("total number of customers = ",df.First_Name.count())
# Out:
# total number of customers =  19

# %%
df[df.Street.str.contains('Hog')]
# Out:
#            First_Name Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1012            Harry    Potter           NaN       Yes             No
# 1016              Ron   Weasley  123-545-5421        No             No
#
#                           Street   City
# CustomerID
# 1012        2394 Hogwarts Avenue  Other
# 1016        2395 Hogwarts Avenue  Other

# %%
df.dtypes
# Out:
# First_Name        object
# Last_Name         object
# Phone_Number      object
# Purchased         object
# Do_Not_Contact    object
# Street            object
# City              object
# dtype: object

# %%
df[df.First_Name.str.contains('Les')]
# Out:
#            First_Name Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1014           Leslie     Knope  876-678-3469       Yes             No
#
#                       Street   City
# CustomerID
# 1014        343 City Parkway  Other

# %%
city = ['Shire','New York']
df[df.City.isin(city)]
# Out:
# Empty DataFrame
# Columns: [First_Name, Last_Name, Phone_Number, Purchased, Do_Not_Contact, Street, City]
# Index: []

# %%
df[df['City']=='Pennsylvania']
# Out:
# Empty DataFrame
# Columns: [First_Name, Last_Name, Phone_Number, Purchased, Do_Not_Contact, Street, City]
# Index: []

# %%
df.filter(like='Hogwarts',axis=0)
# Out:
# Empty DataFrame
# Columns: [First_Name, Last_Name, Phone_Number, Purchased, Do_Not_Contact, Street, City]
# Index: []

# %%
df.filter(items=['2395 Hogwarts Avenue'],axis=0)
# Out:
# Empty DataFrame
# Columns: [First_Name, Last_Name, Phone_Number, Purchased, Do_Not_Contact, Street, City]
# Index: []

# %%
df.loc[1017]
# Out:
# First_Name                Michael
# Last_Name                    Scott
# Phone_Number          123-643-9775
# Purchased                      Yes
# Do_Not_Contact                  No
# Street            121 Paper Avenue
# City                  Pennsylvania
# Name: 1017, dtype: object

# %%
df.iloc[16]
# Out:
# First_Name                Michael
# Last_Name                    Scott
# Phone_Number          123-643-9775
# Purchased                      Yes
# Do_Not_Contact                  No
# Street            121 Paper Avenue
# City                  Pennsylvania
# Name: 1017, dtype: object

# %%
df.sort_values(by=['First_Name','Last_Name'])
# Out:
#            First_Name   Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1002             Abed       Nadir  123-643-9775        No            Yes
# 1020           Anakin   Skywalker  876-678-3469       Yes             No
# 1018            Clark        Kent           NaN       Yes             No
# 1013              Don      Draper  123-543-2345       Yes             No
# 1004           Dwight     Schrute  123-543-2345       Yes            Yes
# 1001            Frodo     Baggins  123-545-5421       Yes             No
# 1009          Gandalf     Unknown           NaN       Yes             No
# 1012            Harry      Potter           NaN       Yes             No
# 1007             Jeff      Winger           NaN        No             No
# 1005              Jon        Snow  876-678-3469       Yes             No
# 1014           Leslie       Knope  876-678-3469       Yes             No
# 1017         Michael        Scott  123-643-9775       Yes             No
# ...

# %%
df.sort_values(by=['First_Name','Last_Name'],ascending = False)
# Out:
#            First_Name   Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1003           Walter       White           NaN        No             No
# 1015             Toby  Flenderson  304-762-2467        No             No
# 1008         Sherlock      Holmes  876-678-3469        No             No
# 1011          Samwise      Gamgee           NaN       Yes             No
# 1016              Ron     Weasley  123-545-5421        No             No
# 1006              Ron     Swanson  304-762-2467       Yes            Yes
# 1010            Peter      Parker  123-545-5421       Yes             No
# 1017         Michael        Scott  123-643-9775       Yes             No
# 1014           Leslie       Knope  876-678-3469       Yes             No
# 1005              Jon        Snow  876-678-3469       Yes             No
# 1007             Jeff      Winger           NaN        No             No
# 1012            Harry      Potter           NaN       Yes             No
# ...

# %%
df.rename(columns={'Purchased':'Payed'})
# Out:
#            First_Name   Last_Name  Phone_Number Payed Do_Not_Contact  \
# CustomerID
# 1001            Frodo     Baggins  123-545-5421   Yes             No
# 1002             Abed       Nadir  123-643-9775    No            Yes
# 1003           Walter       White           NaN    No             No
# 1004           Dwight     Schrute  123-543-2345   Yes            Yes
# 1005              Jon        Snow  876-678-3469   Yes             No
# 1006              Ron     Swanson  304-762-2467   Yes            Yes
# 1007             Jeff      Winger           NaN    No             No
# 1008         Sherlock      Holmes  876-678-3469    No             No
# 1009          Gandalf     Unknown           NaN   Yes             No
# 1010            Peter      Parker  123-545-5421   Yes             No
# 1011          Samwise      Gamgee           NaN   Yes             No
# 1012            Harry      Potter           NaN   Yes             No
# ...

# %%
names=['Ron','Clark','Anakin']
df[df['First_Name'].isin(names)]
# Out:
#            First_Name  Last_Name  Phone_Number Purchased Do_Not_Contact  \
# CustomerID
# 1006              Ron    Swanson  304-762-2467       Yes            Yes
# 1016              Ron    Weasley  123-545-5421        No             No
# 1018            Clark       Kent           NaN       Yes             No
# 1020           Anakin  Skywalker  876-678-3469       Yes             No
#
#                           Street       City
# CustomerID
# 1006            768 City Parkway      Other
# 1016        2395 Hogwarts Avenue      Other
# 1018             3498 Super Lane      Other
# 1020           910 Tatooine Road   Tatooine
