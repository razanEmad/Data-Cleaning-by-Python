# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\razan\Downloads\us-shein-mens_clothes-1891.csv")
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition   price discount       rank-title  \
# 0     10k+ sold recently  $11.99      -7%              NaN
# ...

# %%
df.duplicated().any()
# Out:
# True

# %%
df[df.duplicated()]
# Out:
#       color-count                                   goods-title-link  \
# 120           6.0  Men's Round Neck Casual & Business Letter Prin...
# 122           8.0  ROMWE Street Life Men's Skull & Paisley Print ...
# 123           5.0        Manfinity Men Tropical & Letter Graphic Tee
# 124          16.0                  Men Drawstring Waist Track Shorts
# 126           6.0  Manfinity Chillmode Men Tropical Print Tee & D...
# ...           ...                                                ...
# 1784         11.0  Men'S Color Block Striped Letter Printed Polo ...
# 1785          4.0      Men Spider & Letter Graphic Drop Shoulder Tee
# 1786          4.0            Men Figure Graphic Raglan Sleeve Jacket
# 1787          NaN  Manfinity Homme Men's Contrast Color Trim Over...
# 1788          NaN  2pcs Men's Summer Casual Outfit, Colorblock Sh...
#
#       selling_proposition   price discount       rank-title  \
# 120                   NaN   $4.78     -49%  #10 Best Seller
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition   price discount       rank-title  \
# 0     10k+ sold recently  $11.99      -7%              NaN
# ...

# %%
df.dropna(how='all',inplace=True)
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition   price discount       rank-title  \
# 0     10k+ sold recently  $11.99      -7%              NaN
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition   price discount       rank-title  \
# 0     10k+ sold recently  $11.99      -7%              NaN
# ...

# %%
df['price']=df['price'].str.lstrip('$')
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition  price discount       rank-title  \
# 0     10k+ sold recently  11.99      -7%              NaN
# ...

# %%
df['price']=df['price'].astype('float')
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition  price discount       rank-title  \
# 0     10k+ sold recently  11.99      -7%              NaN
# ...

# %%
df['discount']=df['discount'].str.strip('-%')
df.rename(columns={'discount':'discount percentage'})
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition  price discount       rank-title  \
# 0     10k+ sold recently  11.99        7              NaN
# ...

# %%
df = df.rename(columns={'discount':'discount percentage'})
df
# Out:
#       color-count                                   goods-title-link  \
# 0            15.0  Manfinity Homme Loose Fit Men's Solid Color Bu...
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 3            11.0  Manfinity Homme Men's Contrast Color Short Sle...
# 4             7.0  Manfinity EMRG Loose Fit Men Plus Letter Print...
# ...           ...                                                ...
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
# 1889          4.0  Manfinity Hypemode Men's Loose Fit Pleated Fol...
#
#      selling_proposition  price discount percentage       rank-title  \
# ...

# %%
df[df['color-count'].isnull()]
# Out:
#       color-count                                   goods-title-link  \
# 1             NaN  Manfinity Joysei Men's Star Patterned Shorts W...
# 2             NaN  Men's Summer Casual Short Sleeve T-Shirt With ...
# 10            NaN  ROMWE Street Life Men's 2pcs Slogan Printed Sh...
# 16            NaN  Manfinity Homme Men Solid Button Up Shirt & Sh...
# 17            NaN  Manfinity Hypemode Manfinity Hypemode Men's Me...
# ...           ...                                                ...
# 1883          NaN          Manfinity Men's Floral Print Beach Shorts
# 1885          NaN  Manfinity Men's Vacation Zebra-Print Drawstrin...
# 1886          NaN  GAWX Men's Casual Color-Block Slogan Printed T...
# 1887          NaN  Manfinity Hypemode Men Pocket Front Drawstring...
# 1888          NaN                DAZY Men Patched Pocket Denim Shirt
#
#      selling_proposition  price discount percentage       rank-title  \
# ...

# %%
df.drop(columns=['color-count'],inplace=True)
df
# Out:
#                                        goods-title-link selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...  10k+ sold recently
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                 NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                 NaN
# 3     Manfinity Homme Men's Contrast Color Short Sle...  10k+ sold recently
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...   30+ sold recently
# ...                                                 ...                 ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                 NaN
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...   10+ sold recently
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                 NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                 NaN
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...  600+ sold recently
#
#       price discount percentage       rank-title  \
# ...

# %%
df[df['selling_proposition'].isnull()]
# Out:
#                                        goods-title-link selling_proposition  \
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                 NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                 NaN
# 5     Manfinity Hypemode Loose Fit Men's Cotton Jean...                 NaN
# 6     Manfinity Hypemode Men Solid Button Up Shirt &...                 NaN
# 9     Manfinity Homme Men Plus Size Summer Casual So...                 NaN
# ...                                                 ...                 ...
# 1881  Manfinity Swimmode Men Cow Print Drawstring Wa...                 NaN
# 1883          Manfinity Men's Floral Print Beach Shorts                 NaN
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                 NaN
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                 NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                 NaN
#
#       price discount percentage       rank-title  \
# ...

# %%
df=df.rename(columns={'rank-title':'best seller rank'})
df
# Out:
#                                        goods-title-link selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...  10k+ sold recently
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                 NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                 NaN
# 3     Manfinity Homme Men's Contrast Color Short Sle...  10k+ sold recently
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...   30+ sold recently
# ...                                                 ...                 ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                 NaN
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...   10+ sold recently
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                 NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                 NaN
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...  600+ sold recently
#
#       price discount percentage best seller rank  \
# ...

# %%
df['selling_proposition']=df['selling_proposition'].str.rstrip('+ sold recently')
df
# Out:
#                                        goods-title-link selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...                 10k
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                 NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                 NaN
# 3     Manfinity Homme Men's Contrast Color Short Sle...                 10k
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                  30
# ...                                                 ...                 ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                 NaN
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                  10
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                 NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                 NaN
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                 600
#
#       price discount percentage best seller rank  \
# ...

# %%
k=df['selling_proposition'].str.contains('k',na=False)
k
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1885    False
# 1886    False
# 1887    False
# 1888    False
# 1889    False
# Name: selling_proposition, Length: 1803, dtype: bool

# %%
df.loc[k,'selling_proposition']=df.loc[k,'selling_proposition'].str.replace('k','').astype('float')*1000
df['selling_proposition']=df['selling_proposition'].astype('float')
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  NaN
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  NaN
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                  NaN
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df['best seller rank']=df['best seller rank'].str.strip('# Best Seller	')
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  NaN
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  NaN
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  NaN
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  NaN
# 1888                DAZY Men Patched Pocket Denim Shirt                  NaN
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df['selling_proposition']=df['selling_proposition'].fillna(0)
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  0.0
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  0.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  0.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  0.0
# 1888                DAZY Men Patched Pocket Denim Shirt                  0.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df[df['best seller rank'].isnull()]
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# 7     Men's Summer Letter Printed Short Sleeve Round...                 80.0
# 8     Manfinity Homme Men's Simple Print/Pattern/Let...               3800.0
# ...                                                 ...                  ...
# 1880         DAZY Men Solid Button Front Corduroy Shirt               1200.0
# 1882            Men's Striped T-Shirt With Letter Print               2200.0
# 1884                Manfinity Men Half Button Solid Tee                200.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df.drop(columns=['best seller rank'],inplace=True)
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  0.0
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  0.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  0.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  0.0
# 1888                DAZY Men Patched Pocket Denim Shirt                  0.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df[df['discount percentage'].isnull()]
# Out:
# Empty DataFrame
# Columns: [goods-title-link, selling_proposition, price, discount percentage, rank-sub]
# Index: []

# %%
df['discount percentage']=df['discount percentage'].fillna(0)
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  0.0
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  0.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  0.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  0.0
# 1888                DAZY Men Patched Pocket Denim Shirt                  0.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
# ...

# %%
df[df['price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [goods-title-link, selling_proposition, price, discount percentage, rank-sub]
# Index: []

# %%
df[df['goods-title-link'].isnull()]
# Out:
# Empty DataFrame
# Columns: [goods-title-link, selling_proposition, price, discount percentage, rank-sub]
# Index: []

# %%
df[df['rank-sub'].isnull()]
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# 7     Men's Summer Letter Printed Short Sleeve Round...                 80.0
# 8     Manfinity Homme Men's Simple Print/Pattern/Let...               3800.0
# ...                                                 ...                  ...
# 1880         DAZY Men Solid Button Front Corduroy Shirt               1200.0
# 1882            Men's Striped T-Shirt With Letter Print               2200.0
# 1884                Manfinity Men Half Button Solid Tee                200.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
#       price discount percentage rank-sub
# ...

# %%
df.drop(columns=['rank-sub'],inplace=True)
df
# Out:
#                                        goods-title-link  selling_proposition  \
# 0     Manfinity Homme Loose Fit Men's Solid Color Bu...              10000.0
# 1     Manfinity Joysei Men's Star Patterned Shorts W...                  0.0
# 2     Men's Summer Casual Short Sleeve T-Shirt With ...                  0.0
# 3     Manfinity Homme Men's Contrast Color Short Sle...              10000.0
# 4     Manfinity EMRG Loose Fit Men Plus Letter Print...                 30.0
# ...                                                 ...                  ...
# 1885  Manfinity Men's Vacation Zebra-Print Drawstrin...                  0.0
# 1886  GAWX Men's Casual Color-Block Slogan Printed T...                 10.0
# 1887  Manfinity Hypemode Men Pocket Front Drawstring...                  0.0
# 1888                DAZY Men Patched Pocket Denim Shirt                  0.0
# 1889  Manfinity Hypemode Men's Loose Fit Pleated Fol...                600.0
#
#       price discount percentage
# ...
