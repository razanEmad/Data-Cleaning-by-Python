# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\razan\Downloads\Assignments Data Analysis\8 - Data Cleaning Python Assignments\fifa_data.csv")
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df=df.drop(columns=['Photo','Flag','Loaned From'])
df
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 0               0  158023            L. Messi   31   Argentina       94
# 1               1   20801   Cristiano Ronaldo   33    Portugal       94
# 2               2  190871           Neymar Jr   26      Brazil       92
# 3               3  193080              De Gea   27       Spain       91
# 4               4  192985        K. De Bruyne   27     Belgium       91
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential                 Club  \
# 0             94         FC Barcelona
# ...

# %%
df=df.drop(columns='Club Logo')
df
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 0               0  158023            L. Messi   31   Argentina       94
# 1               1   20801   Cristiano Ronaldo   33    Portugal       94
# 2               2  190871           Neymar Jr   26      Brazil       92
# 3               3  193080              De Gea   27       Spain       91
# 4               4  192985        K. De Bruyne   27     Belgium       91
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential                 Club    Value   Wage  Special Preferred Foot  \
# ...

# %%
pd.set_option('display.max.columns',None)
df
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 0               0  158023            L. Messi   31   Argentina       94
# 1               1   20801   Cristiano Ronaldo   33    Portugal       94
# 2               2  190871           Neymar Jr   26      Brazil       92
# 3               3  193080              De Gea   27       Spain       91
# 4               4  192985        K. De Bruyne   27     Belgium       91
# ...           ...     ...                 ...  ...         ...      ...
# 18202       18202  238813        J. Lundstram   19     England       47
# 18203       18203  243165  N. Christoffersson   19      Sweden       47
# 18204       18204  241638           B. Worman   16     England       47
# 18205       18205  246268      D. Walker-Rice   17     England       47
# 18206       18206  246269           G. Nugent   16     England       46
#
#        Potential                 Club    Value   Wage  Special Preferred Foot  \
# ...

# %%
df=df.drop(columns='Unnamed: 0')
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club    Value   Wage  Special Preferred Foot  \
# ...

# %%
df=df.set_index('ID')
df
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 158023            L. Messi   31   Argentina       94         94
# 20801    Cristiano Ronaldo   33    Portugal       94         94
# 190871           Neymar Jr   26      Brazil       92         93
# 193080              De Gea   27       Spain       91         93
# 192985        K. De Bruyne   27     Belgium       91         92
# ...                    ...  ...         ...      ...        ...
# 238813        J. Lundstram   19     England       47         65
# 243165  N. Christoffersson   19      Sweden       47         63
# 241638           B. Worman   16     England       47         67
# 246268      D. Walker-Rice   17     England       47         66
# 246269           G. Nugent   16     England       46         66
#
#                        Club    Value   Wage  Special Preferred Foot  \
# ID
# 158023         FC Barcelona  €110.5M  €565K     2202           Left
# ...

# %%
df=df.drop(columns='Jersey Number')
df
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 158023            L. Messi   31   Argentina       94         94
# 20801    Cristiano Ronaldo   33    Portugal       94         94
# 190871           Neymar Jr   26      Brazil       92         93
# 193080              De Gea   27       Spain       91         93
# 192985        K. De Bruyne   27     Belgium       91         92
# ...                    ...  ...         ...      ...        ...
# 238813        J. Lundstram   19     England       47         65
# 243165  N. Christoffersson   19      Sweden       47         63
# 241638           B. Worman   16     England       47         67
# 246268      D. Walker-Rice   17     England       47         66
# 246269           G. Nugent   16     England       46         66
#
#                        Club    Value   Wage  Special Preferred Foot  \
# ID
# 158023         FC Barcelona  €110.5M  €565K     2202           Left
# ...

# %%
df=df.drop(columns='Real Face')
df
# Out:
#                       Name  Age Nationality  Overall  Potential  \
# ID
# 158023            L. Messi   31   Argentina       94         94
# 20801    Cristiano Ronaldo   33    Portugal       94         94
# 190871           Neymar Jr   26      Brazil       92         93
# 193080              De Gea   27       Spain       91         93
# 192985        K. De Bruyne   27     Belgium       91         92
# ...                    ...  ...         ...      ...        ...
# 238813        J. Lundstram   19     England       47         65
# 243165  N. Christoffersson   19      Sweden       47         63
# 241638           B. Worman   16     England       47         67
# 246268      D. Walker-Rice   17     England       47         66
# 246269           G. Nugent   16     England       46         66
#
#                        Club    Value   Wage  Special Preferred Foot  \
# ID
# 158023         FC Barcelona  €110.5M  €565K     2202           Left
# ...

# %%
df=df.rename(columns={"RB": "Running Back",
    "ST": "Striker",
    "LWB": "Left Wing Back",
    "RWB": "Right Wing Back",
    "LB": "Left Back",
    "FB": "Full Back",
    "CB": "Centerback",
    "CF": "Centre Forward",
    "LS": "Left Striker",
    "LW": "Left Wing",
    "LF": "Left Forward",
    "RF": "Right Forward",
    "RW": "Right Wing",
    "CAM": "Central Attacking Midfielder",
    "LAM": "Left Attacking Midfielder",
    "RAM": "Right Attacking Midfielder",
    "LM": "Left Midfielder",
    "RCM": "Right Central Midfielder",
    "LCM": "Left Central Midfielder",
    "RM": "Right Midfielder",
    "LDM": "Left Defensive Midfielder",
    "CDM": "Centre Defensive Midfielder",
    "RDM": "Right Defensive Midfielder",
    "LCB": "Left Centreback",
    "RCB": "Right Centreback",
    "Potential": "Potential Ability",
    "Overall" : "Overall Rating",
    "Value" :"Player Value",
    "GkDiving": "Goal Keeper Diving",
    "GKHandling": "Goal Keeper Handling",
    "GKKicking": "Goal Keeper Kicking",
    "GKPositioning": "Goal Keeper Positioning",
    "GKReflexes": "Goal Keeper Reflexes",
    "FKAccuracy" : "Free Kick Accuracy",
    "CM":"Centre Midfielder",
    "RS":"Right Striker"
})
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value   Wage  Special  \
# ID
# 158023                 94         FC Barcelona      €110.5M  €565K     2202
# 20801                  94             Juventus         €77M  €405K     2228
# ...

# %%
df=df.rename(columns={"GKDiving": "Goal Keeper Diving"})
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value   Wage  Special  \
# ID
# 158023                 94         FC Barcelona      €110.5M  €565K     2202
# 20801                  94             Juventus         €77M  €405K     2228
# ...

# %%
df.isnull().sum()
# Out:
# Name                          0
# Age                           0
# Nationality                   0
# Overall Rating                0
# Potential Ability             0
#                            ...
# Goal Keeper Handling         48
# Goal Keeper Kicking          48
# Goal Keeper Positioning      48
# Goal Keeper Reflexes         48
# Release Clause             1564
# Length: 81, dtype: int64

# %%
df[df['Goal Keeper Kicking'].isnull()]
# Out:
#                   Name  Age       Nationality  Overall Rating  \
# ID
# 177971      J. McNulty   33          Scotland              62
# 195380      J. Barrera   29         Nicaragua              62
# 139317        J. Stead   35           England              62
# 240437     A. Semprini   20             Italy              62
# 209462      R. Bingham   24           England              62
# 219702    K. Dankowski   21            Poland              62
# 225590       I. Colman   23         Argentina              62
# 233782       M. Feeney   19           England              62
# 239158        R. Minor   30           Denmark              62
# 242998          Klauss   21            Brazil              62
# 244022      I. Sissoko   22            France              62
# 189238         F. Hart   28           Austria              62
# 211511   L. McCullough   24  Northern Ireland              62
# 224055       Li Yunqiu   27          China PR              62
# ...

# %%
df['Goal Keeper Kicking'].isnull().sum()
# Out:
# 48

# %%
df=df.dropna(subset='Goal Keeper Kicking')
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value   Wage  Special  \
# ID
# 158023                 94         FC Barcelona      €110.5M  €565K     2202
# 20801                  94             Juventus         €77M  €405K     2228
# ...

# %%
df[df['Goal Keeper Kicking'].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
df.isnull().sum()
# Out:
# Name                          0
# Age                           0
# Nationality                   0
# Overall Rating                0
# Potential Ability             0
#                            ...
# Goal Keeper Handling          0
# Goal Keeper Kicking           0
# Goal Keeper Positioning       0
# Goal Keeper Reflexes          0
# Release Clause             1516
# Length: 81, dtype: int64

# %%
df[df['Club'].isnull()]
# Out:
#                   Name  Age Nationality  Overall Rating  Potential Ability  \
# ID
# 207439      L. Paredes   24   Argentina              80                 85
# 156713    A. Granqvist   33      Sweden              80                 80
# 229909        A. Lunev   26      Russia              79                 81
# 187347    I. Smolnikov   29      Russia              79                 79
# 187607       A. Dzyuba   29      Russia              78                 78
# ...                ...  ...         ...             ...                ...
# 245164        V. Kaith   21       India              55                 64
# 243131        K. Taimi   26     Finland              55                 57
# 233526        S. Passi   23       India              54                 63
# 236452  D. Lalhlimpuia   20       India              54                 67
# 234508        C. Singh   21       India              53                 62
#
#        Club Player Value Wage  Special Preferred Foot  \
# ID
# ...

# %%
pd.set_option('display.max.rows',None)
df.dtypes
# Out:
# Name                             object
# Age                               int64
# Nationality                      object
# Overall Rating                    int64
# Potential Ability                 int64
# Club                             object
# Player Value                     object
# Wage                             object
# Special                           int64
# Preferred Foot                   object
# International Reputation        float64
# Weak Foot                       float64
# Skill Moves                     float64
# Work Rate                        object
# Body Type                        object
# Position                         object
# Joined                           object
# Contract Valid Until             object
# Height                           object
# Weight                           object
# Left Striker                     object
# Striker                          object
# Right Striker                    object
# ...

# %%
df['Club']=df['Club'].astype(str)
df.dtypes
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\400030551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Club']=df['Club'].astype(str)
# Name                             object
# Age                               int64
# Nationality                      object
# Overall Rating                    int64
# Potential Ability                 int64
# Club                             object
# Player Value                     object
# Wage                             object
# Special                           int64
# Preferred Foot                   object
# International Reputation        float64
# Weak Foot                       float64
# Skill Moves                     float64
# Work Rate                        object
# ...

# %%
df[df['Club'].isnull()]
# Out:
# Empty DataFrame
# ...

# %%
pd.reset_option('display.max.rows')

# %%
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value   Wage  Special  \
# ID
# 158023                 94         FC Barcelona      €110.5M  €565K     2202
# 20801                  94             Juventus         €77M  €405K     2228
# ...

# %%
df.loc[:, 'Club'] = df['Club'].fillna('Other')

# %%
df['Player Value']=df['Player Value'].str.strip()
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\2615608913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player Value']=df['Player Value'].str.strip()
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# ...

# %%
df['Player Value']=df['Player Value'].str.lstrip('€')
df['Wage']=df['Wage'].str.lstrip('€')
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\3958027852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player Value']=df['Player Value'].str.lstrip('€')
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\3958027852.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wage']=df['Wage'].str.lstrip('€')
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# ...

# %%
df['Player Value'].str.contains('M')
# Out:
# ID
# 158023     True
# 20801      True
# 190871     True
# 193080     True
# 192985     True
#           ...
# 238813    False
# 243165    False
# 241638    False
# 246268    False
# 246269    False
# Name: Player Value, Length: 18159, dtype: bool

# %%
pd.set_option('display.max.rows',None)
df.dtypes
# Out:
# Name                             object
# Age                               int64
# Nationality                      object
# Overall Rating                    int64
# Potential Ability                 int64
# Club                             object
# Player Value                     object
# Wage                             object
# Special                           int64
# Preferred Foot                   object
# International Reputation        float64
# Weak Foot                       float64
# Skill Moves                     float64
# Work Rate                        object
# Body Type                        object
# Position                         object
# Joined                           object
# Contract Valid Until             object
# Height                           object
# Weight                           object
# Left Striker                     object
# Striker                          object
# Right Striker                    object
# ...

# %%
df['Player Value']=df['Player Value'].astype('str')
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\2021980149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player Value']=df['Player Value'].astype('str')

# %%
(df['Player Value'].dtype)
# Out:
# dtype('O')

# %%
df.loc[:,'Player Value'] = df['Player Value'].fillna('0').astype('str')

# %%
df.dtypes
# Out:
# Name                             object
# Age                               int64
# Nationality                      object
# Overall Rating                    int64
# Potential Ability                 int64
# Club                             object
# Player Value                     object
# Wage                             object
# Special                           int64
# Preferred Foot                   object
# International Reputation        float64
# Weak Foot                       float64
# Skill Moves                     float64
# Work Rate                        object
# Body Type                        object
# Position                         object
# Joined                           object
# Contract Valid Until             object
# Height                           object
# Weight                           object
# Left Striker                     object
# Striker                          object
# Right Striker                    object
# ...

# %%
pd.reset_option('display.max.rows')
pd.set_option('display.max.rows',50)
df[df['Player Value'].str.contains('M')]
# Out:
#                      Name  Age Nationality  Overall Rating  Potential Ability  \
# ID
# 158023           L. Messi   31   Argentina              94                 94
# 20801   Cristiano Ronaldo   33    Portugal              94                 94
# 190871          Neymar Jr   26      Brazil              92                 93
# 193080             De Gea   27       Spain              91                 93
# 192985       K. De Bruyne   27     Belgium              91                 92
# ...                   ...  ...         ...             ...                ...
# 239948           S. Reyes   20      Mexico              64                 78
# 241266        W. Geubbels   16      France              64                 86
# 229516            Mayoral   21       Spain              64                 79
# 232104           D. James   20       Wales              64                 79
# 225738       Kuki Zalazar   20       Spain              64                 80
#
# ...

# %%
df['Player Value 1']=df['Player Value'].str.contains('M')
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\309162844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player Value 1']=df['Player Value'].str.contains('M')
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# ...

# %%
df['Release Clause']=df['Release Clause'].str.lstrip('€')
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\1652026968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Release Clause']=df['Release Clause'].str.lstrip('€')
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# ...

# %%
df['Player Value'] = df['Player Value'].apply(lambda x: float(x.replace('M', '')) * 1000000 if 'M' in x else float(x.replace('K', '')) * 1000 if 'K' in x else x)
df['Wage'] = df['Wage'].apply(lambda x: float(x.replace('K', '')) * 1000 if 'K' in x else x)
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\3392636191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player Value'] = df['Player Value'].apply(lambda x: float(x.replace('M', '')) * 1000000 if 'M' in x else float(x.replace('K', '')) * 1000 if 'K' in x else x)
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\3392636191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wage'] = df['Wage'].apply(lambda x: float(x.replace('K', '')) * 1000 if 'K' in x else x)

# %%
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value      Wage  \
# ID
# 158023                 94         FC Barcelona  110500000.0  565000.0
# 20801                  94             Juventus   77000000.0  405000.0
# ...

# %%
df['Weight']=df['Weight'].str.rstrip('lbs')
df=df.rename(columns={'Weight':'Weight (lbs)'})
df
# Out:
# C:\Users\razan\AppData\Local\Temp\ipykernel_30796\1637924548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].str.rstrip('lbs')
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# ...

# %%
df['Joined']=df['Joined'].str.split(',').str[1]
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value      Wage  \
# ID
# 158023                 94         FC Barcelona  110500000.0  565000.0
# 20801                  94             Juventus   77000000.0  405000.0
# ...

# %%
df['Body Type']=df['Body Type'].apply(lambda x: 'Lean' if x== 'Lean' else 'Normal')
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value      Wage  \
# ID
# 158023                 94         FC Barcelona  110500000.0  565000.0
# 20801                  94             Juventus   77000000.0  405000.0
# ...

# %%
df.drop(columns=['Player Value 1','f_n','s_n'],inplace=True)
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value      Wage  \
# ID
# 158023                 94         FC Barcelona  110500000.0  565000.0
# 20801                  94             Juventus   77000000.0  405000.0
# ...

# %%
df
# Out:
#                       Name  Age Nationality  Overall Rating  \
# ID
# 158023            L. Messi   31   Argentina              94
# 20801    Cristiano Ronaldo   33    Portugal              94
# 190871           Neymar Jr   26      Brazil              92
# 193080              De Gea   27       Spain              91
# 192985        K. De Bruyne   27     Belgium              91
# ...                    ...  ...         ...             ...
# 238813        J. Lundstram   19     England              47
# 243165  N. Christoffersson   19      Sweden              47
# 241638           B. Worman   16     England              47
# 246268      D. Walker-Rice   17     England              47
# 246269           G. Nugent   16     England              46
#
#         Potential Ability                 Club Player Value      Wage  \
# ID
# 158023                 94         FC Barcelona  110500000.0  565000.0
# 20801                  94             Juventus   77000000.0  405000.0
# ...

# %%
df[df['Release Clause'].isnull()]
# Out:
#                     Name  Age Nationality  Overall Rating  Potential Ability  \
# ID
# 198710      J. Rodríguez   26    Colombia              88                 89
# 167664        G. Higuaín   30   Argentina              88                 88
# 187961          Paulinho   29      Brazil              85                 85
# 212523  Anderson Talisca   24      Brazil              83                 90
# 207410        M. Kovačić   24     Croatia              83                 89
# ...                  ...  ...         ...             ...                ...
# 241341        Zhang Yuan   21    China PR              51                 60
# 241444           Chen Ji   21    China PR              50                 59
# 243506          Zhou Xin   20    China PR              50                 61
# 244872         L. Valeau   19       Italy              50                 65
# 53748      K. Pilkington   44     England              48                 48
#
# ...

# %%
df['Release Clause']=df['Release Clause'].fillna(0)

# %%
df
