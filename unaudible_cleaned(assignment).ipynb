# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\razan\Downloads\Assignments Data Analysis\8 - Data Cleaning Python Assignments\audible_uncleaned.csv")
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df['del']=df['author'].str.split(pat=':').str[0]
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df['author_name']=df['author'].str.split(pat=':').str[1]
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df=df.drop(columns='del')
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df['narrator_name']=df['narrator'].str.split(pat=':').str[1]
df['dl']=df['narrator'].str.split(pat=':').str[0]
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df=df.drop(columns='dl')
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df=df.drop(columns='language')
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df=df.drop(columns=['author','narrator'])
df
# Out:
#                                              name                time  \
# 0                      Geronimo Stilton #11 & #12   2 hrs and 20 mins
# 1                                The Burning Maze   13 hrs and 8 mins
# 2                                    The Deep End    2 hrs and 3 mins
# 3                            Daughter of the Deep  11 hrs and 16 mins
# 4      The Lightning Thief: Percy Jackson, Book 1              10 hrs
# ...                                           ...                 ...
# 87484                   Last Days of the Bus Club   7 hrs and 34 mins
# 87485                                    The Alps   10 hrs and 7 mins
# 87486                        The Innocents Abroad   19 hrs and 4 mins
# 87487                       A Sentimental Journey    4 hrs and 8 mins
# 87488                                      Havana     6 hrs and 1 min
#
#       releasedate                          stars   price      author_name  \
# ...

# %%
df['time']=df['time'].str.rstrip(' mins ') 
df
# Out:
#                                              name           time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2 hrs and 20    04-08-08
# 1                                The Burning Maze   13 hrs and 8    01-05-18
# 2                                    The Deep End    2 hrs and 3    06-11-20
# 3                            Daughter of the Deep  11 hrs and 16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1          10 hr    13-01-10
# ...                                           ...            ...         ...
# 87484                   Last Days of the Bus Club   7 hrs and 34    09-03-17
# 87485                                    The Alps   10 hrs and 7    21-02-17
# 87486                        The Innocents Abroad   19 hrs and 4    30-12-16
# 87487                       A Sentimental Journey    4 hrs and 8    23-02-11
# 87488                                      Havana    6 hrs and 1    07-03-17
#
# ...

# %%
df['time'] = df['time'].str.replace(' hrs and ',':')
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1  10 hr    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name
# ...

# %%
df['time'] = df['time'].str.replace(' hr','')
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name
# ...

# %%
df['star']=df['stars'].str.split ('stars').str[0] 
df['del']=df['stars'].str.split ('stars').str[1] 
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name  \
# ...

# %%
df['star'] = df['star'].str.replace(' out of 5', '')
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name  \
# ...

# %%
df=df.rename(columns={'del':'no. ratings'})
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name  \
# ...

# %%
df['no. ratings'] = df['no. ratings'].str.replace(' ratings', '')
df
# Out:
#                                              name   time releasedate  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08
# 1                                The Burning Maze   13:8    01-05-18
# 2                                    The Deep End    2:3    06-11-20
# 3                            Daughter of the Deep  11:16    05-10-21
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# ...                                           ...    ...         ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17
# 87485                                    The Alps   10:7    21-02-17
# 87486                        The Innocents Abroad   19:4    30-12-16
# 87487                       A Sentimental Journey    4:8    23-02-11
# 87488                                      Havana    6:1    07-03-17
#
#                                stars   price      author_name   narrator_name  \
# ...

# %%
df=df.drop(columns='stars')
df
# Out:
#                                              name   time releasedate   price  \
# 0                      Geronimo Stilton #11 & #12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df['name'] = df['name'].str.replace('#', '')
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
pd.set_option('display.max.rows',50)
df[df['name'].str.contains(r'[^a-zA-Z0-9 ]')].head(50)
# Out:
#                                                   name      time releasedate  \
# 0                             Geronimo Stilton 11 & 12      2:20    04-08-08
# 4           The Lightning Thief: Percy Jackson, Book 1        10    13-01-10
# 5                    The Hunger Games: Special Edition     10:35    30-10-18
# 9                                    The Tyrant’s Tomb     13:22    24-09-19
# 10            The Titan's Curse: Percy Jackson, Book 3      8:48    14-01-10
# 11             Magic Tree House Collection: Books 9-16      5:23    24-08-11
# 12              Magic Tree House Collection: Books 1-8       6:1    27-09-11
# 21               Eldest: The Inheritance Cycle, Book 2     23:29    14-04-09
# 23                            Geronimo Stilton 22 & 24      2:37    01-02-11
# 25                                     Winnie-the-Pooh      2:46    28-12-03
# 26            Magic Tree House Collection: Books 25-32       7:9    01-09-20
# ...

# %%
df['time'] = df['time'].str.replace(' and ', ':')
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df.head(50)
# Out:
#                                                  name   time releasedate  \
# 0                            Geronimo Stilton 11 & 12   2:20    04-08-08
# 1                                    The Burning Maze   13:8    01-05-18
# 2                                        The Deep End    2:3    06-11-20
# 3                                Daughter of the Deep  11:16    05-10-21
# 4          The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# 5                   The Hunger Games: Special Edition  10:35    30-10-18
# 6                         Quest for the Diamond Sword   2:23    25-11-14
# 7                                   The Dark Prophecy  12:32    02-05-17
# 8                           Merlin Mission Collection  10:56    02-05-17
# 9                                   The Tyrant’s Tomb  13:22    24-09-19
# 10           The Titan's Curse: Percy Jackson, Book 3   8:48    14-01-10
# 11            Magic Tree House Collection: Books 9-16   5:23    24-08-11
# ...

# %%
df['author_name']=df['author_name'].str.replace(r'([A-Z])',r' \1',regex=True)
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df.head(50)
# Out:
#                                                  name   time releasedate  \
# 0                            Geronimo Stilton 11 & 12   2:20    04-08-08
# 1                                    The Burning Maze   13:8    01-05-18
# 2                                        The Deep End    2:3    06-11-20
# 3                                Daughter of the Deep  11:16    05-10-21
# 4          The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# 5                   The Hunger Games: Special Edition  10:35    30-10-18
# 6                         Quest for the Diamond Sword   2:23    25-11-14
# 7                                   The Dark Prophecy  12:32    02-05-17
# 8                           Merlin Mission Collection  10:56    02-05-17
# 9                                   The Tyrant’s Tomb  13:22    24-09-19
# 10           The Titan's Curse: Percy Jackson, Book 3   8:48    14-01-10
# 11            Magic Tree House Collection: Books 9-16   5:23    24-08-11
# ...

# %%
df['narrator_name1']=df['narrator_name'].str.split(pat=',').str[0]
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df['narrator_name2']=df['narrator_name'].str.split(pat=',').str[1]
df['narrator_name3']=df['narrator_name'].str.split(pat=',').str[2]
df.head(50)
# Out:
#                                                  name   time releasedate  \
# 0                            Geronimo Stilton 11 & 12   2:20    04-08-08
# 1                                    The Burning Maze   13:8    01-05-18
# 2                                        The Deep End    2:3    06-11-20
# 3                                Daughter of the Deep  11:16    05-10-21
# 4          The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# 5                   The Hunger Games: Special Edition  10:35    30-10-18
# 6                         Quest for the Diamond Sword   2:23    25-11-14
# 7                                   The Dark Prophecy  12:32    02-05-17
# 8                           Merlin Mission Collection  10:56    02-05-17
# 9                                   The Tyrant’s Tomb  13:22    24-09-19
# 10           The Titan's Curse: Percy Jackson, Book 3   8:48    14-01-10
# 11            Magic Tree House Collection: Books 9-16   5:23    24-08-11
# ...

# %%
df['narrator_name2'].isnull().sum()
# Out:
# 75754

# %%
df=df.drop(columns=['narrator_name2','narrator_name3'])
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df=df.drop(columns='narrator_name')
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df['narrator_name1']=df['narrator_name1'].str.replace(r'([A-Z])',r' \1',regex=True)

df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df.head(50)
# Out:
#                                                  name   time releasedate  \
# 0                            Geronimo Stilton 11 & 12   2:20    04-08-08
# 1                                    The Burning Maze   13:8    01-05-18
# 2                                        The Deep End    2:3    06-11-20
# 3                                Daughter of the Deep  11:16    05-10-21
# 4          The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# 5                   The Hunger Games: Special Edition  10:35    30-10-18
# 6                         Quest for the Diamond Sword   2:23    25-11-14
# 7                                   The Dark Prophecy  12:32    02-05-17
# 8                           Merlin Mission Collection  10:56    02-05-17
# 9                                   The Tyrant’s Tomb  13:22    24-09-19
# 10           The Titan's Curse: Percy Jackson, Book 3   8:48    14-01-10
# 11            Magic Tree House Collection: Books 9-16   5:23    24-08-11
# ...

# %%
df=df.rename(columns={'narrator_name1':'narrator_name'})
df
# Out:
#                                              name   time releasedate   price  \
# 0                        Geronimo Stilton 11 & 12   2:20    04-08-08  468.00
# 1                                The Burning Maze   13:8    01-05-18  820.00
# 2                                    The Deep End    2:3    06-11-20  410.00
# 3                            Daughter of the Deep  11:16    05-10-21  615.00
# 4      The Lightning Thief: Percy Jackson, Book 1     10    13-01-10  820.00
# ...                                           ...    ...         ...     ...
# 87484                   Last Days of the Bus Club   7:34    09-03-17  596.00
# 87485                                    The Alps   10:7    21-02-17  820.00
# 87486                        The Innocents Abroad   19:4    30-12-16  938.00
# 87487                       A Sentimental Journey    4:8    23-02-11  680.00
# 87488                                      Havana    6:1    07-03-17  569.00
#
# ...

# %%
df.head(50)
# Out:
#                                                  name   time releasedate  \
# 0                            Geronimo Stilton 11 & 12   2:20    04-08-08
# 1                                    The Burning Maze   13:8    01-05-18
# 2                                        The Deep End    2:3    06-11-20
# 3                                Daughter of the Deep  11:16    05-10-21
# 4          The Lightning Thief: Percy Jackson, Book 1     10    13-01-10
# 5                   The Hunger Games: Special Edition  10:35    30-10-18
# 6                         Quest for the Diamond Sword   2:23    25-11-14
# 7                                   The Dark Prophecy  12:32    02-05-17
# 8                           Merlin Mission Collection  10:56    02-05-17
# 9                                   The Tyrant’s Tomb  13:22    24-09-19
# 10           The Titan's Curse: Percy Jackson, Book 3   8:48    14-01-10
# 11            Magic Tree House Collection: Books 9-16   5:23    24-08-11
# ...
